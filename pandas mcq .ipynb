# %%
import pandas as pd

movies_df=pd.read_csv(r'C:\Users\ssdalvi\Downloads\Movies (1).csv')
movies_df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3848  Color      Shane Carruth                   143.0      77.0
# 3849  Color   Neill Dela Llana                    35.0      80.0
# 3850  Color   Robert Rodriguez                    56.0      81.0
# 3851  Color       Edward Burns                    14.0      95.0
# 3852  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
null_counts= movies_df.isnull().sum()

num_columns_with_nulls = null_counts[null_counts > 0].count()
print(num_columns_with_nulls
# Out:
# 12

# %%
#What is the count of columns in the new dataframe?
df_combined = df_combined.drop(['color', 'director_name','actor_1_facebook_likes','actor_2_facebook_likes','actor_2_facebook_likes'], axis=1)
# Out:
# (3853, 28)

# %%
#Which column has the highest percentage of null values?

null_percentages = (null_counts / len(movies_df)) * 100
high_percentage_null_values = null_percentages.idxmax()
print(high_percentage_null_values)

max_null_percentage = null_percentages.max()
print(max_null_percentage)
# Out:
# aspect_ratio
# 1.8686737607059436

# %%
# Calculate the percentage of null values in each column
null_percentages = (movies_df.isnull().sum() / len(movies_df)) * 100

# Print the null percentages
print(null_percentages)

# Compare the null percentages
print("Column with highest percentage of null values:", null_percentages.idxmax())
print("Highest percentage of null values:", null_percentages.max())
print("Column with lowest percentage of null values:", null_percentages.idxmin())
print("Lowest percentage of null values:", null_percentages.min())
# Out:
# color                        0.051908
# director_name                0.000000
# num_critic_for_reviews       0.025954
# duration                     0.025954
# director_facebook_likes      0.000000
# actor_3_facebook_likes       0.155723
# actor_2_name                 0.025954
# actor_1_facebook_likes       0.000000
# gross                        0.000000
# genres                       0.000000
# actor_1_name                 0.000000
# movie_title                  0.000000
# num_voted_users              0.000000
# cast_total_facebook_likes    0.000000
# actor_3_name                 0.155723
# facenumber_in_poster         0.155723
# plot_keywords                0.778614
# movie_imdb_link              0.000000
# num_user_for_reviews         0.000000
# language                     0.103815
# country                      0.000000
# content_rating               1.245783
# budget                       0.000000
# title_year                   0.000000
# actor_2_facebook_likes       0.025954
# ...

# %%
round(100*(movies_df.isnull().sum()/len(movies_df.index)), 2)
# Out:
# color                        0.05
# director_name                0.00
# num_critic_for_reviews       0.03
# duration                     0.03
# director_facebook_likes      0.00
# actor_3_facebook_likes       0.16
# actor_2_name                 0.03
# actor_1_facebook_likes       0.00
# gross                        0.00
# genres                       0.00
# actor_1_name                 0.00
# movie_title                  0.00
# num_voted_users              0.00
# cast_total_facebook_likes    0.00
# actor_3_name                 0.16
# facenumber_in_poster         0.16
# plot_keywords                0.78
# movie_imdb_link              0.00
# num_user_for_reviews         0.00
# language                     0.10
# country                      0.00
# content_rating               1.25
# budget                       0.00
# title_year                   0.00
# actor_2_facebook_likes       0.03
# imdb_score                   0.00
# aspect_ratio                 1.87
# ...

# %%
# What is the count of movies made in the English language after replacing the NaN values with English?

Count_of_movies = len(movies_df[movies_df['language'].fillna("English") == "English"])
Count_of_movies
# Out:
# 3675

# %%
Count_of_movies=[(movies_df.loc[:,['language']]).fillna("English") == "English"]
Count_of_movies
# Out:
# [      language
#  0         True
#  1         True
#  2         True
#  3         True
#  4         True
#  ...        ...
#  3848      True
#  3849      True
#  3850     False
#  3851      True
#  3852      True
#
#  [3853 rows x 1 columns]]

# %%
#Which movie is ranked 5th from the top in the list based on the net profit obtained?

#Note: net profit = gross - budget
# Calculate net profit


# Sort the DataFrame by IMDb score in descending order
movies_df_sorted = movies_df.sort_values(by='imdb_score', ascending=False)

# Extract the top 250 movies
IMDb_Top_250 = movies_df_sorted.head(250)

# Print the new DataFrame
print(IMDb_Top_250)

movies_df['net_profit'] = movies_df['gross'] - movies_df['budget']

# Sort the DataFrame by net profit in descending order
movies_df_sorted = movies_df.sort_values(by='net_profit', ascending=False)

# Get the 5th row (since indexing starts at 0)
fifth_ranked_movie = movies_df_sorted.iloc[4]

# Print the title of the 5th ranked movie

print(fifth_ranked_movie)
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1795  Color        Frank Darabont                   199.0     142.0
# 3016  Color  Francis Ford Coppola                   208.0     175.0
# 2543  Color  Francis Ford Coppola                   149.0     220.0
# 64    Color     Christopher Nolan                   645.0     152.0
# 325   Color         Peter Jackson                   328.0     192.0
# ...     ...                   ...                     ...       ...
# 677   Color            Doug Liman                   249.0     119.0
# 1734  Color          Pierre Morel                   309.0      93.0
# 86    Color              Don Hall                   384.0     102.0
# 746   Color         Cameron Crowe                   149.0     152.0
# 157   Color          Dean DeBlois                   292.0     102.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1795                      0.0                   461.0   Jeffrey DeMunn
# ...

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = movies_df.sort_values(by = 'imdb_score', ascending = False).head(250)
IMDb_Top_250
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1795  Color        Frank Darabont                   199.0     142.0
# 3016  Color  Francis Ford Coppola                   208.0     175.0
# 2543  Color  Francis Ford Coppola                   149.0     220.0
# 64    Color     Christopher Nolan                   645.0     152.0
# 325   Color         Peter Jackson                   328.0     192.0
# ...     ...                   ...                     ...       ...
# 677   Color            Doug Liman                   249.0     119.0
# 1734  Color          Pierre Morel                   309.0      93.0
# 86    Color              Don Hall                   384.0     102.0
# 746   Color         Cameron Crowe                   149.0     152.0
# 157   Color          Dean DeBlois                   292.0     102.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1795                      0.0                   461.0   Jeffrey DeMunn
# ...

# %%
IMDb_Top_250 = movies_df.sort_values(by = 'imdb_score', ascending = False)
IMDb_Top_250 = IMDb_Top_250.loc[IMDb_Top_250.num_voted_users > 25000]
IMDb_Top_250 = IMDb_Top_250.iloc[:250, ]
IMDb_Top_250['Rank'] = range(1,251)
IMDb_Top_250['Rank']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 7
#       4 IMDb_Top_250['Rank'] = range(1,251)
#       5 IMDb_Top_250['Rank']
# ----> 7 import matplotlib.pyplot as plt
#       8 plt.hist(IMDb_Top_250['imdb_score'], bins = 5, range = (7.5,10), edgecolor = 'cyan')
#       9 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
movies_df['profit'] = movies_df['gross'] - movies_df['budget']
top_10 = movies_df.sort_values(by = 'profit', ascending = False).head(10)
top_10
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 28    Color    Colin Trevorrow                   644.0     124.0
# 25    Color      James Cameron                   315.0     194.0
# 2704  Color       George Lucas                   282.0     125.0
# 2748  Color   Steven Spielberg                   215.0     120.0
# 16    Color        Joss Whedon                   703.0     173.0
# 482   Color       Roger Allers                   186.0      73.0
# 230   Color       George Lucas                   320.0     136.0
# 64    Color  Christopher Nolan                   645.0     152.0
# 419   Color          Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 28                      365.0                  1000.0         Judy Greer
# ...

# %%
# Define the buckets
buckets = [7.5, 8, 8.5, 9, 9.5, 10]

# Create a new column 'bucket' and assign each movie to a bucket
IMDb_Top_250['bucket'] = pd.cut(IMDb_Top_250['imdb_score'], bins=buckets, include_lowest=True)

# Count the number of movies in each bucket
bucket_counts = IMDb_Top_250['bucket'].value_counts()

# Find the bucket with the maximum number of movies
max_bucket = bucket_counts.idxmax()

print(f"The bucket with the maximum number of movies is: {max_bucket}")
# Out:
# The bucket with the maximum number of movies is: (8.0, 8.5]

# %%
# Calculate the average rating for each actor
actor_ratings = movies_df.groupby('actor_2_name')['imdb_score'].mean().reset_index()

# Sort the actors by their average rating in descending order
actor_ratings_sorted = actor_ratings.sort_values(by='imdb_score', ascending=False)

# Print the highest rated actor
print("Highest rated actor:", actor_ratings_sorted.iloc[0]['actor_2_name'])
print("Average rating:", actor_ratings_sorted.iloc[0]['imdb_score'])
# Out:
# Highest rated actor: Jeffrey DeMunn
# Average rating: 8.9

# %%
# Importing the pandas package
import pandas as pd

# Reading the dataframe
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/XWvQjYY4LZWdxLvPWOj2pPwn/heart.csv')

df.columns = map(lambda x: str(x).capitalize(), df.columns)

# Printing the final columns. Do not edit this part.
print(df.columns)
# Out:
# Index(['Age', 'Sex', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach',
#        'Exang', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'Target'],
#       dtype='object')

# %%
#Risk of Diabetes Based on BMI
#Description
#You've been given the pima_indian_diabetes dataset. Here are its first few rows:﻿
#Notice the BMI and Diabetes column. You need to find the BMI which is most likely to cause Diabetes. First round the BMI to an integer value and return which BMI has the most risk of diabetes based on the 0, 1 diabetes values provided in the dataframe.

#Expected Output: Just print a single integer denoting the value of the required BMI. (Please only output an integer value. For example, if the output is 30.0 please convert it to int and output 30.). 

# Import the Pandas package
import pandas as pd 

# Reading the input dataframe
pima = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/pLZK3n22ezVwAG2XOYW5qEx7V/pima_indian_diabetes.csv')

# Round the BMI to an integer value
pima['BMI'] = pima['BMI'].round().astype(int)

# Group by BMI and count the number of diabetes cases
diabetes_count = pima[pima['Diabetes'] == 1].groupby('BMI').size().reset_index(name='count')

# Find the BMI with the highest count of diabetes cases
max_count_BMI = diabetes_count.loc[diabetes_count['count'].idxmax()]['BMI']

# Print the result
print(int(max_count_BMI))
# Out:
# 34

# %%
# Importing the pandas package
import pandas as pd

# Reading the dataframe
movies = pd.read_csv('https://query.data.world/s/lqdline2c7rnci4bf4dwjsok6d26jd')

# Print out the indices of the rows in which both these columns have missing values
print(list(movies[(movies['actor_1_facebook_likes'].isnull()) & (movies['actor_2_facebook_likes'].isnull())].index))

# Drop these particular rows
movies = movies.drop(movies[(movies['actor_1_facebook_likes'].isnull()) & (movies['actor_2_facebook_likes'].isnull())].index)

# Print the number of retained rows in the dataframe
print(len(movies))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...
